# %%
import pandas as pd
import Levenshtein as lvs

item_table = pd.read_csv("tables/items_example.csv")

# %%
item_table["ITENS"].tolist()
# Out:
# ['Camisa tecido malha PV 30.1, modelo tipo polo, 67% viscose, 33% poliester, manga curta.',
#  'Calça de Tecido 67% algodão 33% poliester, sarja 3x1',
#  'Boné  de Tecido 67% algodão 33% poliester, sarja 2x1',
#  'Jaqueta  de Tecido 67% algodão 33% poliester, sarja 3x1',
#  'Sapato de proteção sem cano',
#  'Capa de chuva, manga longa, com faixas refletivas',
#  'Luvas de malha tricotada',
#  'Protetor solar FPS 30',
#  'Calça de Tecido, 67% Algodão e 33% Poliéster, Sarja 3/1',
#  'Camisa de Tecido de Malha PV 30.1, modelo tipo Polo, 67% Viscose e 33% Poliéster',
#  'Boné  de Tecido, 67% Algodão e 33% Poliéster , sarja 2x1',
#  'Jaqueta  de Tecido 67% Algodão e 33% Poliéster',
#  'Capa Contra Chuva com Manga Longa',
#  'Sapato de Proteção Sem Cano',
#  'Luvas de Vaqueta com punhos de Raspa',
#  'Creme Bloqueador Solar UVA/UVB FPS 30',
#  'Luvas Nitrílica (para dias de chuva)',
#  'Calça de Tecido, 67% Algodão e 33% Poliéster, Sarja 3/1',
# ...

# %%
item_table.iloc

# %%
var1 = "Luvas Nitrílica (para dias de chuva)"
var2 = "Luvas Nitrílica"

lvs.distance(var1,var2)
# Out:
# 21

# %%
import table_formatter as tf

formatter = tf.Formatter(item_table,"ITENS")

# %%
for i in range(0,-1):
    print(i)

# %%
import table_formatter as tf
import pandas as pd
import Levenshtein as lvs

table = pd.read_csv("tables/items_example.csv")
formatter = tf.Formatter(table,"ITENS")
fmt_table = table
shf_table = table.sample(frac=1,random_state=1235)
shf_formatter = tf.Formatter(shf_table,"ITENS")

print(lvs.distance(str(formatter),str(shf_formatter)))
# Out:
# 26

# %%
pd.set_option("display.max_rows", None)  # Show all rows
pd.set_option("display.max_columns", None)  # Show all columns
table.sort_values("ITENS").reset_index(drop=True)
# Out:
#                                                 ITENS   VALOR
# 0                                    Avental em raspa   37.86
# 1   Boné  de Tecido 67% algodão 33% poliester, sar...   26.97
# 2   Boné  de Tecido 67% algodão 33% poliester, sar...   26.97
# 3   Boné  de Tecido 67% algodão 33% poliester, sar...   26.97
# 4   Boné  de Tecido 67% algodão 33% poliester, sar...   26.97
# 5   Boné  de Tecido, 67% Algodão e 33% Poliéster ,...   26.97
# 6   Boné  de Tecido, 67% Algodão e 33% Poliéster ,...   26.97
# 7   Boné  de Tecido, 67% Algodão e 33% Poliéster ,...   26.97
# 8   Boné  de Tecido, 67% Algodão e 33% Poliéster ,...   26.97
# 9          Bota de PVC cano longo com palmilha de aço   71.44
# 10  Calça de Tecido 67% algodão 33% poliester, sar...   64.27
# 11  Calça de Tecido 67% algodão 33% poliester, sar...   64.27
# 12  Calça de Tecido 67% algodão 33% poliester, sar...   64.27
# 13  Calça de Tecido 67% algodão 33% poliester, sar...   64.27
# ...

# %%
import pandas as pd
pd.__version__
# Out:
# '2.0.1'
